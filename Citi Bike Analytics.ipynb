# %%
import csv
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
citi_bike_jan_22 = pd.read_csv("Resources/202201-citibike-tripdata.csv")
citi_bike_feb_22 = pd.read_csv("Resources/202202-citibike-tripdata.csv")
citi_bike_march_22 = pd.read_csv("Resources/202203-citibike-tripdata.csv")
# Out:
# C:\Users\ellio\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
citi_bike_jan_22

# %%
citi_bike_feb_22

# %%
citi_bike_march_22

# %%
Citi_Bike_2022=pd.concat([citi_bike_jan_22,citi_bike_feb_22,citi_bike_march_22], axis=0)

# %%
Citi_Bike_2022
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 1893439  79E49EA8727CA662   classic_bike  2022-03-30 21:12:45
# 1893440  9C4F6A095779AAE2  electric_bike  2022-03-21 09:33:21
# 1893441  C1966A89B5078124  electric_bike  2022-03-04 14:31:36
# 1893442  A11D1F167EF1B8C6   classic_bike  2022-03-18 18:43:43
# 1893443  74A6A40E386BE88F  electric_bike  2022-03-10 17:21:52
#
#                     ended_at            start_station_name start_station_id  \
# 0        2022-01-18 08:28:18       Boerum Pl\t& Pacific St          4488.09
# ...

# %%
Citi_Bike_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4179576 entries, 0 to 1893443
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 446.4+ MB

# %%
Citi_Bike_2022.isnull().any()
# Out:
# ride_id               False
# rideable_type         False
# started_at            False
# ended_at              False
# start_station_name     True
# start_station_id       True
# end_station_name       True
# end_station_id         True
# start_lat             False
# start_lng             False
# end_lat                True
# end_lng                True
# member_casual         False
# dtype: bool

# %%
Citi_Bike_2022.dropna(how='any',inplace=True)

# %%
Citi_Bike_2022.isnull().any()
# Out:
# ride_id               False
# rideable_type         False
# started_at            False
# ended_at              False
# start_station_name    False
# start_station_id      False
# end_station_name      False
# end_station_id        False
# start_lat             False
# start_lng             False
# end_lat               False
# end_lng               False
# member_casual         False
# dtype: bool

# %%
Citi_Bike_2022
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 1893439  79E49EA8727CA662   classic_bike  2022-03-30 21:12:45
# 1893440  9C4F6A095779AAE2  electric_bike  2022-03-21 09:33:21
# 1893441  C1966A89B5078124  electric_bike  2022-03-04 14:31:36
# 1893442  A11D1F167EF1B8C6   classic_bike  2022-03-18 18:43:43
# 1893443  74A6A40E386BE88F  electric_bike  2022-03-10 17:21:52
#
#                     ended_at            start_station_name start_station_id  \
# 0        2022-01-18 08:28:18       Boerum Pl\t& Pacific St          4488.09
# ...

# %%
rds_connection_string = "(pw):postgre@localhost:5433/Tableau_Citi_Bike"

# %%
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
Citi_Bike_2022.to_sql("Citi_Bike_22_Cleaned", con=engine)
